# %%
# sample structures from each committor slice for visualization

# %%
import sys
import os
import importlib

import numpy as np
import scipy

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import ticker
import seaborn as sns
import prettypyplot as pplt
from cycler import cycler

import pyemma
import mdtraj as md

import ivac
import extq
from extq.stop import forward_stop
import kmedoids

# %%
sys.path.insert(1, "../../python")
sys.path.insert(1, "../../..")
import util
import plotting

# %%
pplt.load_cmaps()
plt.style.use("custom")  # custom style sheet
plt.style.use("muted")  # muted color theme from SciencePlots
colors = mpl.colors.to_rgba_array(
    [
        "#364B9A",
        "#4A7BB7",
        "#6EA6CD",
        "#98CAE1",
        "#C2E4EF",
        "#EAECCC",
        "#FEDA8B",
        "#FDB366",
        "#F67E4B",
        "#DD3D2D",
        "#A50026",
    ]
)
cm_div = mpl.colors.LinearSegmentedColormap.from_list("diverging", colors)
mpl.colormaps.register(cm_div, force=True)
feature_colors = ["grey", "#E46C0A", "#51BD52", "#D85BD8", "#5AA5A5", "#0000FF", "#ffcc00"]

# %%
# %load_ext autoreload
# %autoreload 2

# %%
DATA_DIR = "/project/dinner/scguo/ci-vsd/data"
# S4 translocation/rotation data
cv_trajs = list(
    np.load(f"{DATA_DIR}/raw_feat/cv_dist_spin_anton.npy", allow_pickle=True)
)
cv_trajs.extend(np.load(f"{DATA_DIR}/raw_feat/cv_dist_spin_anton2.npy")[:115])
cv_arr = np.concatenate(cv_trajs)
# salt bridge distances for states
sb_trajs = list(np.load(f"{DATA_DIR}/raw_feat/feat2_raw_anton.npy", allow_pickle=True))
sb_trajs.extend(np.load(f"{DATA_DIR}/raw_feat/feat2_raw_anton2.npy")[:115])
sb_arr = np.concatenate(sb_trajs)
sb_models = np.load(f"{DATA_DIR}/models_centroids_feat2.npy")
# distances to F161
rf161 = list(np.load(f"{DATA_DIR}/raw_feat/rf161.npy", allow_pickle=True))
rf161.extend(np.load(f"{DATA_DIR}/raw_feat/rf161_anton2.npy")[:115])
rf161_arr = np.concatenate(rf161)
# committors
lag = 500
qp_du = np.load(f"{DATA_DIR}/feat2_dist_du_anton2/qp_downup_3.npy", allow_pickle=True)[8] # 50 ns lag time
qm_du = np.load(f"{DATA_DIR}/feat2_dist_du_anton2/qm_downup_3.npy", allow_pickle=True)[8] # 50 ns lag time
# weights
weights = np.load(f"{DATA_DIR}/feat2_dist_du_anton2/weights_3_feat5ivac.npy", allow_pickle=True)[0] # 0.1 ns lag time

# %%
feature_names = []
feature_names.append('Translocation')
feature_names.append('Rotation')
for r in ("R217", "R223", "R226", "R229", "R232"):
    for n in ("D129", "D136", "D151", "D164", "E183", "D186"):
        if n.startswith("D"):
            feature_names.append(f"{r} C$_\\zeta$-{n} C$_\\gamma$")
        else:
            feature_names.append(f"{r} C$_\\zeta$-{n} C$_\\delta$")
for i in ("R223", "R226", "R229"):
    feature_names.append(f"{i}-F161")

# %%
# no c-alpha distances
X = np.hstack((cv_arr, sb_arr[:, 30:], rf161_arr))
y = np.concatenate(qp_du)
print(X.shape, y.shape)
# Out:
# (4150115, 35) (4150115,)

# %% [markdown]
# # Divide into bins of 0.05 and then weight by $\pi$

# %%
topfile = "/project/dinner/scguo/ci-vsd/civsd-pro.psf"

# %%
np.random.seed(123)

# %%
def sample_inds(q, weights, size=None, qstep=0.05, low=0, hi=1):
    q_arr = np.concatenate(q)
    w_arr = np.concatenate(weights)
    nsteps = round((hi - low) / qstep)
    all_inds = []
    steps = np.linspace(low, hi - qstep, nsteps)
    for i, s in enumerate(steps):
        q_inds = ((q_arr >= s) & (q_arr <= s + qstep)).nonzero()[0]
        q_w = w_arr[q_inds] / np.sum(w_arr[q_inds])
        slice_inds = np.random.choice(q_inds, size=size, replace=False, p=q_w)
        all_inds.append(slice_inds)
    return steps, all_inds

# %%
steps, q_inds = sample_inds(qp_du, weights, size=10, qstep=0.05)

# %%
anton_files = []
for i in range(3, 119):
    if i == 82:
        continue
    anton_files.append(f"/project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.{i}.xtc")

# %%
def traj_frame(close_id):
    if close_id < 3_000_000:
        ix = util.anton_frame(close_id)
        file = f"/beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-{ix[0]}.xtc"
        frame = ix[1]
        print(f"{file}\t{frame}")
        return file, frame
    else:
        ix = ((close_id - 3_000_000) // 10001, (close_id - 3_000_000) % 10001)
        print(f"{anton_files[ix[0]]}\t{ix[1]}")
        return anton_files[ix[0]], ix[1]

# %%
def save_frames(file_names, indices, top_file, outfile):
    print(f"Topology file: {top_file}")
    print(f"Output file: {outfile}")

    xyz, angles, lengths = [], [], []
    for (f, idx) in zip(file_names, indices):
        frame = md.load_frame(f, idx, top=top_file)
        # if mdtraj encounters an impossible frame index it just
        # returns a 0-length trajectory
        if len(frame) != 0:
            xyz.append(frame.xyz)
            angles.append(frame.unitcell_angles)
            lengths.append(frame.unitcell_lengths)

    top = md.load_topology(top_file)
    traj = md.Trajectory(
        np.concatenate(xyz),
        top,
        unitcell_angles=np.concatenate(angles),
        unitcell_lengths=np.concatenate(lengths),
    )
    traj.save(outfile)

# %%
files, indices = [], []
for k, inds in enumerate(q_inds):
    for i in inds:
        f, ix = traj_frame(i)
        files.append(f)
        indices.append(ix)
# Out:
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-179.xtc	11947
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-103.xtc	8060
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-58.xtc	9356
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-166.xtc	2396
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-179.xtc	48011
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-154.xtc	4195
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.100.xtc	8325
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-179.xtc	3
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-159.xtc	3840
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-152.xtc	794
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-154.xtc	6888
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.38.xtc	2782
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-172.xtc	5353
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-11.xtc	6974
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-165.xtc	4724
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.40.xtc	6739
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-62.xtc	6327
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-61.xtc	9136
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-179.xtc	63170
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-179.xtc	63334
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.40.xtc	888
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.83.xtc	2204
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.61.xtc	636
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.37.xtc	4068
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.60.xtc	8296
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-177.xtc	8084
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-179.xtc	48791
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-109.xtc	9799
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-154.xtc	8491
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.38.xtc	9038
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-55.xtc	8101
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-208.xtc	2472
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-204.xtc	9026
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.9.xtc	2128
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-204.xtc	5692
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-179.xtc	42399
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-204.xtc	5883
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.99.xtc	829
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.114.xtc	2168
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.9.xtc	4655
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.13.xtc	4764
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-64.xtc	7711
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	1614
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-182.xtc	66595
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.79.xtc	2818
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-120.xtc	5647
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-210.xtc	8216
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.116.xtc	2817
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-235.xtc	7233
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.12.xtc	3103
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-66.xtc	3085
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.51.xtc	8961
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-249.xtc	3710
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-210.xtc	8908
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-182.xtc	15863
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	1577
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-182.xtc	53491
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.13.xtc	6905
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.78.xtc	5636
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-193.xtc	8871
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.13.xtc	4586
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-230.xtc	4625
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-280.xtc	5483
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.14.xtc	8765
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.66.xtc	5856
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-62.xtc	8835
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.43.xtc	7228
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-119.xtc	2633
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-105.xtc	5325
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-219.xtc	9328
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-66.xtc	4991
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.98.xtc	8731
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.28.xtc	768
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.51.xtc	2303
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-15.xtc	2943
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.19.xtc	5215
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.12.xtc	5564
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-105.xtc	2586
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-71.xtc	7129
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.44.xtc	12
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-244.xtc	4147
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.53.xtc	6827
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.39.xtc	5513
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.13.xtc	7704
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.106.xtc	8534
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.96.xtc	5488
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-281.xtc	1223
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-26.xtc	8584
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-235.xtc	8302
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.16.xtc	1730
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.53.xtc	9461
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.114.xtc	8410
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.16.xtc	8491
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.76.xtc	6272
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.42.xtc	8405
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.51.xtc	1082
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-202.xtc	1422
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.19.xtc	6086
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-264.xtc	1540
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.16.xtc	4597
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.25.xtc	5015
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.45.xtc	7534
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	12812
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-195.xtc	1369
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-281.xtc	4154
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.45.xtc	6519
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.102.xtc	6320
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.30.xtc	1590
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.104.xtc	745
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.5.xtc	1196
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-258.xtc	4792
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-280.xtc	514
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-216.xtc	3703
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.49.xtc	7039
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-264.xtc	6330
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-294.xtc	4322
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-294.xtc	7865
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-293.xtc	9446
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-17.xtc	311
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.110.xtc	6531
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.86.xtc	3191
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	66069
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-216.xtc	8301
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-292.xtc	6441
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.86.xtc	2313
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.105.xtc	6059
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-216.xtc	3080
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-293.xtc	3984
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.49.xtc	8138
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-255.xtc	8944
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.23.xtc	988
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	33975
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-257.xtc	620
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.77.xtc	6994
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.105.xtc	6987
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	14974
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	93102
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	43619
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	97853
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-255.xtc	311
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	30650
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	75303
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.90.xtc	9392
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-247.xtc	1403
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-196.xtc	8961
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.23.xtc	3940
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.17.xtc	656
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	23173
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-264.xtc	7181
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.77.xtc	7653
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-185.xtc	69714
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.85.xtc	7421
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-221.xtc	3253
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-221.xtc	5651
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.63.xtc	5485
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	68049
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.63.xtc	5432
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.90.xtc	4646
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.64.xtc	9759
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-250.xtc	7870
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-147.xtc	8679
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-265.xtc	1925
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-185.xtc	60575
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-39.xtc	6413
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-185.xtc	69616
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.22.xtc	938
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-122.xtc	8753
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.89.xtc	1840
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-256.xtc	8611
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-185.xtc	66770
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-185.xtc	59702
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-39.xtc	462
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-218.xtc	3369
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-185.xtc	99489
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-291.xtc	9094
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-45.xtc	1339
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-39.xtc	4079
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-45.xtc	5665
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-130.xtc	6325
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-133.xtc	4523
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-183.xtc	28105
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-37.xtc	6615
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-72.xtc	5777
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-223.xtc	4552
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-137.xtc	2760
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-223.xtc	388
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-16.xtc	9943
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-183.xtc	16940
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.3.xtc	4477
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-183.xtc	52125
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-45.xtc	7180
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-183.xtc	78433
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-83.xtc	7390
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-183.xtc	12523
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-24.xtc	6341
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-142.xtc	5625
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-25.xtc	108
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-183.xtc	87484
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-91.xtc	4026
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-34.xtc	3768

# %%
save_frames(files, indices, topfile, f"../../data/q_bin/q_05_10_pi.dcd")
# Out:
# Topology file: /project/dinner/scguo/ci-vsd/civsd-pro.psf
# Output file: ../../data/q_bin/q_05_10_pi.dcd

# %% [markdown]
# # Weight by reactive density

# %%
piqmqp = [w * qp.clip(min=0, max=1) * qm.clip(min=0, max=1) for (w, qp, qm) in zip(weights, qp_du, qm_du)]
steps, q_inds = sample_inds(qp_du, piqmqp, size=10, qstep=0.05)

# %%
files, indices = [], []
for k, inds in enumerate(q_inds):
    for i in inds:
        f, ix = traj_frame(i)
        files.append(f)
        indices.append(ix)
# Out:
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-166.xtc	3504
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-6.xtc	3398
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-175.xtc	6043
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.116.xtc	127
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-180.xtc	46506
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-168.xtc	8277
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-11.xtc	3635
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-179.xtc	21818
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-176.xtc	2785
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-4.xtc	3953
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.59.xtc	313
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-179.xtc	63432
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-172.xtc	4469
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.58.xtc	5205
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-169.xtc	1451
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-179.xtc	23760
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-64.xtc	319
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-150.xtc	6175
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.69.xtc	5285
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-65.xtc	8032
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-179.xtc	92331
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.118.xtc	1047
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-110.xtc	6179
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.101.xtc	2418
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.101.xtc	4966
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-51.xtc	5882
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-180.xtc	80327
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-280.xtc	3608
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-171.xtc	9820
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-15.xtc	600
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-120.xtc	6539
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-59.xtc	1807
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-120.xtc	4588
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.70.xtc	488
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.100.xtc	223
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-15.xtc	9865
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-178.xtc	6967
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.117.xtc	3093
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.12.xtc	2603
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.28.xtc	9503
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-6.xtc	5581
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-210.xtc	7654
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.116.xtc	5008
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-182.xtc	50159
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-63.xtc	2149
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-202.xtc	7724
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.109.xtc	3396
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-182.xtc	16344
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.54.xtc	3760
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.54.xtc	3745
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-114.xtc	584
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-182.xtc	70236
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.20.xtc	2117
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-182.xtc	48769
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-105.xtc	3451
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.112.xtc	3822
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.10.xtc	5391
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.70.xtc	5910
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-15.xtc	4494
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-120.xtc	4248
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-201.xtc	882
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-26.xtc	8110
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.115.xtc	1324
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-117.xtc	5493
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-182.xtc	35223
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-111.xtc	8918
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-64.xtc	5082
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-117.xtc	3409
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	6657
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.6.xtc	384
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-182.xtc	9617
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-182.xtc	91970
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-10.xtc	4579
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-182.xtc	93826
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-280.xtc	5069
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-105.xtc	3015
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.20.xtc	1156
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-182.xtc	15761
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.28.xtc	5621
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-19.xtc	7791
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.104.xtc	529
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-22.xtc	3806
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-125.xtc	2229
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.76.xtc	8592
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-26.xtc	9126
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.65.xtc	941
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.110.xtc	1350
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.102.xtc	6465
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.64.xtc	300
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.108.xtc	5319
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.25.xtc	1048
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.104.xtc	6685
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.16.xtc	8460
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.108.xtc	7194
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-202.xtc	278
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.109.xtc	3764
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.102.xtc	1727
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.102.xtc	8061
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-195.xtc	1990
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.42.xtc	8867
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-26.xtc	1970
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.50.xtc	2666
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-22.xtc	4906
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-125.xtc	6282
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-247.xtc	3274
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.104.xtc	7306
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-293.xtc	7617
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.27.xtc	30
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.32.xtc	4126
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-247.xtc	3266
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-294.xtc	6681
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.23.xtc	6872
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-255.xtc	9772
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-292.xtc	6300
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-292.xtc	9767
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.86.xtc	7852
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-294.xtc	8384
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.95.xtc	4836
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-294.xtc	4399
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-293.xtc	7295
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-17.xtc	658
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-280.xtc	1313
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.86.xtc	6374
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	61059
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-70.xtc	9211
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-255.xtc	9847
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-255.xtc	4717
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.75.xtc	1023
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-70.xtc	4791
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.86.xtc	5722
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-264.xtc	8676
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.86.xtc	4986
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-257.xtc	3506
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.64.xtc	2702
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	66110
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	69333
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	84767
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.23.xtc	5204
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	78851
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	51024
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.92.xtc	1670
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.90.xtc	1190
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	84577
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-256.xtc	2555
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	71765
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	56202
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	81860
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	80471
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.86.xtc	1973
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.77.xtc	379
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.77.xtc	8550
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.92.xtc	3370
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-250.xtc	6845
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-221.xtc	883
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	85322
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-221.xtc	6918
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-196.xtc	364
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-181.xtc	72346
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-265.xtc	5927
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-248.xtc	132
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-221.xtc	1262
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-93.xtc	8467
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-256.xtc	7353
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-96.xtc	8285
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-122.xtc	8926
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-287.xtc	344
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-221.xtc	721
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-143.xtc	6394
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-218.xtc	1029
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-256.xtc	8528
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.8.xtc	2527
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-183.xtc	13069
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-87.xtc	743
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-185.xtc	72843
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-185.xtc	91900
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-79.xtc	4654
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-209.xtc	6865
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-137.xtc	4092
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-185.xtc	95085
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-87.xtc	6892
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-92.xtc	5000
# /project/dinner/scguo/ci-vsd/anton2/prot/civsd.prot.29.xtc	4668
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-184.xtc	54443
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-209.xtc	5161
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-184.xtc	86205
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-73.xtc	2324
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-138.xtc	8728
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-229.xtc	3446
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-184.xtc	72724
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-16.xtc	6984
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-31.xtc	6240
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-83.xtc	8713
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-291.xtc	5815
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-132.xtc	138
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-82.xtc	1618
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-84.xtc	4216
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-73.xtc	6511
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-95.xtc	7866
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-73.xtc	9688
# /beagle3/dinner/scguo/anton-old/xtc1000ns/civsd-240.xtc	2468

# %%
save_frames(files, indices, topfile, f"../../data/q_bin/q_05_10_piqpqm.dcd")
# Out:
# Topology file: /project/dinner/scguo/ci-vsd/civsd-pro.psf
# Output file: ../../data/q_bin/q_05_10_piqpqm.dcd

# %% [markdown]
# # Interpolate frames

# %%
traj1 = md.load("../../data/q_bin/q_05_10_piqpqm.dcd", top=topfile)
s1s3_backbone = traj1.top.select("resid 1 to 214 and backbone")
# align backbone of helices S1-S3
traj1.superpose(traj1, frame=0, atom_indices=s1s3_backbone)
traj2 = md.load("../../data/q_bin/q_05_10_pi.dcd", top=topfile)
traj2.superpose(traj2, frame=0, atom_indices=s1s3_backbone)
# Out:
# <mdtraj.Trajectory with 200 frames, 2192 atoms, 134 residues, and unitcells at 0x7ff0121abe80>

# %%
def morph_linear(t, N):
    return t / N

def morph_cycle(t, N):
    return (1 - np.cos(np.pi * t / (N + 1))) / 2

def morph_sin2(t, N):
    return np.sqrt(np.sin(np.pi * t / N / 2))
    
def interpolate(xyz, N, morph_fn):
    """Divide each frame into N intermediate morphs
    using interpolated using morph_fn.
    
    xyz : (T, 3) array of coordinates
    N : number of intermediate frames
    
    Returns
    -------
    new_xyz : ((T - 1) * N + 1, 3) array of coordinates
    """
    new_xyz = []
    for i in range(len(xyz) - 1):
        for t in range(N):
            # interpolation value
            f = morph_fn(t, N)
            intermediate_frame = xyz[i] * (1 - f) + xyz[i + 1] * f
            new_xyz.append(intermediate_frame)
    new_xyz.append(xyz[-1])
    return new_xyz

# %%
morphed_traj1 = interpolate(traj1.xyz[0::10], 10, morph_linear)

# %%
top = md.load_topology(topfile)
traj = md.Trajectory(
    morphed_traj1,
    top
)
traj.save("../../data/q_bin/q_05_10_piqpqm_morph.xtc")
